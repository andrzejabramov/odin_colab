# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/drive/MyDrive/data/weight-height.csv")
df
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [10000 rows x 3 columns]

# %%
sns.scatterplot(df, x='Height', y='Weight', hue='Gender')
# Out:
# <Axes: xlabel='Height', ylabel='Weight'>

# %%
sns.histplot(data=df,x='Height', y='Weight', hue='Gender')
# Out:
# <Axes: xlabel='Height', ylabel='Weight'>

# %%
sns.histplot(data=df,x='Height', hue='Gender')
# Out:
# <Axes: xlabel='Height', ylabel='Count'>

# %%
sns.kdeplot(data=df,x='Height',hue='Gender')
# Out:
# <Axes: xlabel='Height', ylabel='Density'>

# %%
sns.barplot(df, x='Gender', y='Height')
# Out:
# <Axes: xlabel='Gender', ylabel='Height'>

# %%
sns.countplot(df, x='Gender')
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.boxplot(df, y='Height', hue='Gender')
# Out:
# <Axes: ylabel='Height'>

# %%
sns.violinplot(df, y='Weight', hue='Gender')
# Out:
# <Axes: ylabel='Weight'>
