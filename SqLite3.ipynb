# %%
import pandas as pd
import sqlite3 as sq

# %%
con = sq.connect("/content/drive/MyDrive/data/sqlite.db")
#cursor = sq.Cursor(con)
cursor = con.cursor()

# %%
sql = "SELECT * FROM sqlite_master WHERE type = 'table'"
cursor.execute(sql)
cursor.fetchall()
# Out:
# [('table',
#   'customers',
#   'customers',
#   2,
#   'CREATE TABLE customers (\n    id INT PRIMARY KEY,\n    name VARCHAR(100),\n    city VARCHAR(50),\n    premium_member BOOLEAN\n)'),
#  ('table',
#   'orders',
#   'orders',
#   4,
#   'CREATE TABLE orders (\n    id INT PRIMARY KEY,\n    customer_id INT,\n    order_date DATE,\n    amount DECIMAL(10,2),\n    FOREIGN KEY (customer_id) REFERENCES customers(id)\n)'),
#  ('table',
#   'products',
#   'products',
#   6,
#   'CREATE TABLE products (\n    id INT PRIMARY KEY,\n    name VARCHAR(100),\n    category VARCHAR(50),\n    price DECIMAL(10,2)\n)')]

# %%
sql1 = "SELECT name FROM sqlite_master WHERE type = 'table'"
cursor.execute(sql1)
cursor.fetchall()
# Out:
# [('customers',), ('orders',), ('products',)]

# %%
tableInfo = "PRAGMA table_info('customers')"
cursor.execute(tableInfo)
cr = cursor.fetchall()
cr
# Out:
# [(0, 'id', 'INT', 0, None, 1),
#  (1, 'name', 'VARCHAR(100)', 0, None, 0),
#  (2, 'city', 'VARCHAR(50)', 0, None, 0),
#  (3, 'premium_member', 'BOOLEAN', 0, None, 0)]

# %%
pd.DataFrame(cr)
# Out:
#    0               1             2  3     4  5
# 0  0              id           INT  0  None  1
# 1  1            name  VARCHAR(100)  0  None  0
# 2  2            city   VARCHAR(50)  0  None  0
# 3  3  premium_member       BOOLEAN  0  None  0

# %%
prod = "SELECT * FROM 'products'"
prod1 = "SELECT * FROM 'products' WHERE category = 'Электроника'"
prod_agg = "SELECT MAX(price), MIN(price), AVG(price), SUM(price), COUNT(price) FROM 'products'"
prod_avg = "SELECT * FROM 'products' WHERE price > (SELECT AVG(price) FROM 'products')"
prod_average = """
  SELECT category, AVG(price)
  FROM 'products'
  GROUP BY category
"""
cust_prem = """
  SELECT * FROM 'customers'
  WHERE city = 'Москва' AND premium_member = true
"""
cust_count = """
  SELECT city, COUNT(city)
  FROM 'customers'
  GROUP BY city
"""
ord = """
  SELECT * FROM 'orders'
  ORDER BY amount DESC
  LIMIT 3
"""
ord_max = """
  SELECT *
  FROM 'orders'
  WHERE amount = (
    SELECT MAX(amount)
    FROM 'orders'
    );
"""
amount_sum = """
  SELECT
    c.name,
    c.city,
    SUM(o.amount)
  FROM 'orders' o
  JOIN 'customers' c
  ON o.customer_id = c.id
  GROUP BY o.customer_id
"""

cursor.execute(amount_sum)

pd.DataFrame(cursor.fetchall())
# Out:
#                 0                1      2
# 0     Иван Петров           Москва  38000
# 1  Мария Сидорова  Санкт-Петербург   7500
# 2  Алексей Иванов           Москва   9800
# 3  Елена Смирнова           Казань  15600
