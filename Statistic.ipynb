# %%
import pandas as pd
from scipy import stats

# %%
df = pd.read_csv("/content/drive/MyDrive/data/weight-height.csv")
df
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [10000 rows x 3 columns]

# %%
df['Height'] = df['Height'] * 2.55
df
# Out:
#       Gender      Height      Weight
# 0       Male  188.309893  241.893563
# 1       Male  175.393855  162.310473
# 2       Male  188.980769  212.740856
# 3       Male  182.913995  220.042470
# 4       Male  178.198579  206.349801
# ...      ...         ...         ...
# 9995  Female  168.740263  136.777454
# 9996  Female  171.021244  170.867906
# 9997  Female  162.863380  128.475319
# 9998  Female  176.037320  163.852461
# 9999  Female  157.957827  113.649103
#
# [10000 rows x 3 columns]

# %%
df['Weight'] = df['Weight'] * 0.4
df
# Out:
#       Gender      Height     Weight
# 0       Male  188.309893  96.757425
# 1       Male  175.393855  64.924189
# 2       Male  188.980769  85.096342
# 3       Male  182.913995  88.016988
# 4       Male  178.198579  82.539920
# ...      ...         ...        ...
# 9995  Female  168.740263  54.710982
# 9996  Female  171.021244  68.347162
# 9997  Female  162.863380  51.390128
# 9998  Female  176.037320  65.540985
# 9999  Female  157.957827  45.459641
#
# [10000 rows x 3 columns]

# %%
df['Height'].plot.density()
# Out:
# <Axes: ylabel='Density'>

# %%
df['Weight'].plot.density()
# Out:
# <Axes: ylabel='Density'>

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      5000
# Female    5000
# Name: count, dtype: int64

# %%
df[df['Gender'] == 'Male']['Height'].plot.density()
# Out:
# <Axes: ylabel='Density'>

# %%
dfMale = df[df['Gender'] == 'Male']
dfFemale = df[df['Gender'] == 'Female']

# %%
dfFemale
# Out:
#       Gender      Height     Weight
# 5000  Female  150.222367  40.835331
# 5001  Female  166.336532  56.522329
# 5002  Female  161.590960  52.416561
# 5003  Female  164.423993  51.268604
# 5004  Female  157.572395  51.912563
# ...      ...         ...        ...
# 9995  Female  168.740263  54.710982
# 9996  Female  171.021244  68.347162
# 9997  Female  162.863380  51.390128
# 9998  Female  176.037320  65.540985
# 9999  Female  157.957827  45.459641
#
# [5000 rows x 3 columns]

# %%
dfFemale['Height'].plot.box()
# Out:
# <Axes: >

# %%
st, p = stats.normaltest(dfFemale['Height'])
print(f"{p:.3f}")
# Out:
# 0.631
